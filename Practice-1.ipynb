# %%
### First Occurance of the element

#naive approch

# def firstoccurance(arr,n,x):
#     for i in range(0,n):
#         if(arr[i]==x):
#             return i


### Efficient Approch

# def firstoccurance(arr,low,high,x):
    
#     if low>high:
#         return -1
    
#     mid = (low+high)//2
#     if x > arr[mid]:
#         return firstoccurance(arr,mid+1,high,x)
#     elif x<arr[mid]:
#         return firstoccurance(arr,low,mid-1,x)
        
#     else:
#         if mid==0 or arr[mid-1]!=arr[mid]:
#             return mid
#         else:
#             firstoccurance(arr,low,mid-1,x)
            
#     return -1
        
    
### More Efficient approch

def firstoccurance(arr,low,high,x):
    
    while low<=high:
        
        mid = (low+high)//2
        
        if x > arr[mid]:
            low = mid+1
        elif x < arr[mid]:
            high = mid-1
            
        else:
            if mid==0 or arr[mid-1]!=arr[mid]:
                return mid
            else:
                high = mid-1
                
    return -1

arr = [10,20,20,20,30,30]
# n = len(arr)
low = 0
high = len(arr)-1
x= 30
firstoccurance(arr,low,high,x)
# Out:
# 4

# %%
### Last Occurance of the element

def lastoccurance(arr,low,high,x):
    while low<=high:
        mid = (low+high)//2
        
        if x>arr[mid]:
            low = mid+1
        elif x < arr[mid]:
            high = mid-1
            
        else:
            if mid==len(arr)-1 or arr[mid]!=arr[mid+1]:
                return mid
            else:
                low = mid+1
                
                
arr = [10,20,20,20,30,30]
# n = len(arr)
low = 0
high = len(arr)-1
x= 30
lastoccurance(arr,low,high,x)
# Out:
# 5

# %%
def firstIndex(l, x):
    low = 0

    high = len(l) - 1

    while low <= high:

        mid = (low + high) // 2

        if l[mid] > x:
            high = mid - 1
        elif l[mid] < x:
            low = mid + 1

        else:
            if mid == 0 or l[mid - 1] != l[mid]:
                return mid
            else:
                high = mid - 1
    return -1


def lastOccur(l, x):
    low = 0
    high = len(l) - 1

    while low <= high:

        mid = (low + high) // 2

        if l[mid] < x:
            low = mid + 1

        elif l[mid] > x:
            high = mid - 1

        else:

            if mid == len(l) - 1 or l[mid] != l[mid + 1]:
                return mid
            else:
                low = mid + 1
    return -1


def countOccurr(l, x):
    first = firstIndex(l, x)

    if first == -1:
        return 0

    else:
        return lastOccur(l, x) - first + 1


l = [10, 20, 20, 20, 30, 30]

print(10, countOccurr(l, 10))
print(20, countOccurr(l, 20))
print(30, countOccurr(l, 30))
# Out:
# 10 1
# 20 3
# 30 2

# %%
## Count the occurance of the one's

def countOne(arr):
    count = 0
    for i in range(len(arr)):
        if arr[i]==1:
            count+=1
            
    return count

# %%
def countone(arr,n):
    low = 0
    high = n-1
    while (low<=high):
        mid = (low+high)//2
        
        if(arr[mid]<1):
            high = mid-1
            
        elif (arr[mid]>1):
            low = mid+1
            
        else:
            if(mid==n-1 or arr[mid+1]!=1):
                return mid+1
            else:
                low = mid+1
                
    return

arr = [1,1,1,1,0,0,0,0]
n = len(arr)
print("count of 1s in the array",countone(arr,n))
# Out:
# count of 1s in the array 4

# %%
### Square Root

def root(x):
    low = 1
    high = x
    ans = -1
    
    while low<=high:
        mid = (low+high)//2
        msq = mid*mid
        if msq==x:
            return mid
        elif msq>x:
            high = mid-1
        else:
            low = mid+1
            ans = mid
            
    return 0

x = 4
root(x)
# Out:
# 2

# %%
## Sorting

# %%
### Inversion Sort

def inverSort(arr):
    n = len(arr)
    res = 0
    for i in range(n-1):
        for j in range(i+1,n):
            if arr[i]>arr[j]:
                res+=1
                
    return res

arr = [2,4,1,3,5]
inverSort(arr)
# Out:
# 3

# %%
### Efficient approch

def countMerge(arr,l,m,r):
    left = arr[l:m+1]
    right = arr[m+1:r+1]
    
    res,i,j,k = 0,0,0,l
    while i<len(left) and j<len(right):
        if left[i]<=right[j]:
            arr[k] = left[i]
            i+=1
        else:
            arr[k]=right[j]
            j+=1
            res += (len(left)-i)
            
        k+=1
        
        while i < len(left):
            arr[k] = left[i]
            i+=1
            k+=1
            
        while j<len(right):
            arr[k] = right[j]
            j+=1
            k+=1
            
    return res

# %%
def mergeSort(arr, n):
	temp_arr = [0]*n
	return _mergeSort(arr, temp_arr, 0, n-1)

def _mergeSort(arr, temp_arr, left, right):

	inv_count = 0

	if left < right:

		mid = (left + right)//2

		inv_count += _mergeSort(arr, temp_arr,
								left, mid)

		inv_count += _mergeSort(arr, temp_arr,
								mid + 1, right)


		inv_count += merge(arr, temp_arr, left, mid, right)
	return inv_count


def merge(arr, temp_arr, left, mid, right):
	i = left	 
	j = mid + 1 
	k = left	 
	inv_count = 0

	while i <= mid and j <= right:

		if arr[i] <= arr[j]:
			temp_arr[k] = arr[i]
			k += 1
			i += 1
		else:
			temp_arr[k] = arr[j]
			inv_count += (mid-i + 1)
			k += 1
			j += 1

	while i <= mid:
		temp_arr[k] = arr[i]
		k += 1
		i += 1

	while j <= right:
		temp_arr[k] = arr[j]
		k += 1
		j += 1

	for loop_var in range(left, right + 1):
		arr[loop_var] = temp_arr[loop_var]

	return inv_count


arr = [1, 20, 6, 4, 5]
n = len(arr)
result = mergeSort(arr, n)
print("Number of inversions are",result)
# Out:
# Number of inversions are 5

# %%
def partition(arr,p):
    n = len(arr)
    arr[p],arr[n-1] = arr[n-1],arr[p]
    temp = []
    for x in arr:
        if x<=arr[n-1]:
            temp.append(x)
    for x in arr:
        if x>arr[n-1]:
            temp.append(x)
            
    for i in range(len(arr)):
        arr[i] = temp[i]
        
        return temp
        
        
arr = [5,13,6,9,12,8,11]
p = 5
partition(arr,p)
# Out:
# [5, 6, 8, 13, 9, 12, 11]

# %%
### Lomuto Partition

def lomutoPartition(arr,l,h):
    pivot = arr[h]
    i = l-1
    
    for j in range(l,h):
        if arr[j]<=pivot:
            i+=1
            arr[i],arr[j] = arr[j],arr[i]
            
    arr[i+1],arr[h],arr[h],arr[i+1]
    
    return i+1

arr = [5,13,6,9,12,8,11]
l=0
h = len(arr)-1
lomutoPartition(arr,l,h)
print(*arr)
# Out:
# 5 6 9 8 12 13 11

# %%
def hoarePartitions(arr,l,h):
    pivot = arr[l]
    i = l-1
    j = h+1
    
    while True:
        i = i+1
        while arr[i]<pivot:
            i = i+1
        j = j-1
        while arr[j]>pivot:
            j = j-1
        if i>=j:
            return j
        arr[i],arr[j] = arr[j], arr[i]

# %%
## Quick Sort

def partition(arr,l,h):
    pivot = arr[h]
    i = l-1
    for j in range(l,h):
        if arr[j]<=pivot:
            i+=1
            arr[i],arr[j] = arr[j],arr[i]
            
    arr[i+1],arr[h] = arr[h],arr[i+1]
    
    return i+1

def quickSort(arr,l,h):
    if l<h:
        p = partition(arr,l,h)
        quickSort(arr,l,p-1)
        quickSort(arr,p+1,h)
        
arr = [5,13,6,9,12,8,11]
l=0
h = len(arr)-1
quickSort(arr,l,h)
print(*arr)
# Out:
# 5 6 8 9 11 12 13

# %%
### List

# %%
def leftrotate(l,d):
    for i in range(0,d):
        l.append(l.pop(0))
        
l = [10,20,30,40,50]
d = 3
leftrotate(l,d)
print(l)
# Out:
# [40, 50, 10, 20, 30]

# %%
def reverse(l,b,e):
    while b<e:
        l[b],l[e]=l[e],l[b]
        b+=1
        e-=1
        
def leftRotate(l,d):
    n = len(l)
    reverse(l,0,d-1)
    reverse(l,d,n-1)
    reverse(l,0,n-1)
    
l = [10,20,30,40,50]
d = 3
leftRotate(l,d)
print(l)
# Out:
# [40, 50, 10, 20, 30]

# %%
### Maximum value in the of the array

def maxValue(arr,n):
    res = arr[0]-arr[1]
    for i in range(0,n-1):
        for j in range(i+1,n):
            res = max(res,arr[j]-arr[i])
#             print(arr[j],arr[i],arr[j]-arr[i])
            
    return res

arr = [2,3,10,6,4,8,1]
n = len(arr)
maxValue(arr,n)
# Out:
# 8

# %%
 def maxDiff(arr,n):
        res = arr[1]-arr[0]
        minval = arr[0]
        for i in range(1,n):
            res = max(res,arr[i]-minval)
            minval = min(arr[i],minval)
            
        return res
    
arr = [2,3,10,6,4,8,1]
n = len(arr)
maxDiff(arr,n)
# Out:
# 8

# %%
### Buy and sell of the stock

def maxProfit(price,n):
    profit = 0
    for i in range(1,n):
        if price[i]>price[i-1]:
            profit+=price[i]-price[i-1]
            print(profit)
    return profit

arr = [1,5,3,8,12]
maxProfit(arr,len(arr))
# Out:
# 4
# 9
# 13
# 13

# %%
## Trapping rain water 

def getWater(arr,n):
    res = 0
    for i in range(1,n-1):
        lmax = arr[i]
        for j in range(0,i):
            lmax = max(lmax,arr[j])
        rmax = arr[j]
        for j in range(i+1,n):
            rmax = max(rmax,arr[j])
        res = res+(min(lmax,rmax)-arr[j])
        
    return res

arr = [5,0,6,2,3]
n = len(arr)
getWater(arr,n)
# Out:
# 5

# %%
## Efficient
def getWater(arr,n):
    res = 0
    lmax = [0]*n
    rmax = [0]*n
    
    lmax[0] = arr[0]
    for i in range(1,n):
        lmax[i] = max(arr[i],lmax[i-1])
        
    rmax[n-1] = arr[n-1]
    for i in range(n-2,-1,-1):
        rmax[i] = max(arr[i],rmax[i+1])
        
    for i in range(1,n-1):
        res = res+(min(lmax[i],rmax[i])-arr[i])
        
    return res


arr = [5,0,6,2,3]
n=len(arr)
getWater(arr,n)
# Out:
# 6

# %%
### Maximum sum of the subarray

def maxSum(arr,n,k):
    if(n<k):
        print("Invalid")
        return -1
    
    res = 0
    for i in range(k):
        res+=arr[i]
        print(res)
        
        
    curr_sum = res
    print("==========")
    print(curr_sum)
    for i in range(k,n):
        curr_sum+=arr[i]-arr[i-k]
        print(curr_sum)
        res = max(res,curr_sum)
        
    return res

arr = [100,200,300,400]
k=2
maxSum(arr,len(arr),k)
# Out:
# 100
# 300
# ...
# 300
# 500
# 700
# 700

# %%
### lenght of the longest subarray weith even and odd

# def maxEvenodd(arr,n):
#     res = 1
#     for i in range(0,n-1):
#         curr = 1
#         for j in range(i+1,n):
#             if(arr[j]%2==0 and arr[j-1]%2!=0) or (arr[j-1]%2==0 and arr[j]!=0):
#                 curr+=1
#             else:
#                 break
                
#             res = max(res,curr)
            
#     return res



def maxEvenodd(arr,n):
    res = 1
    curr = 1
    for i in range(1,n):
        if(arr[i]%2==0 and arr[i-1]%2!=0) or (arr[i-1]%2==0 and arr[i]%2!=0):
            curr+=1
            res = max(res,curr)
        else:
            curr=1
            
    return res
        

arr = [10,13,12,11,9,9]
n = len(arr)
maxEvenodd(arr,n)
# Out:
# 4

# %%
### Circular sub array sum

def normalMaxSum(arr,n):
    res = 1
    curr = 1
    for i in range(1,n):
        if(arr[i]%2==0 and arr[i-1]%2!=0) or (arr[i-1]%2==0 and arr[i]%2!=0):
            curr+=1
            res = max(res,curr)
            
        else:
            curr = 1
            
    return res

def overallMaxsum(arr,n):
    max_normal = normalMaxSum(arr,n)
    if max_normal<0:
        return 0
    
    arr_sum = 0
    for i in range(0,n):
        arr_sum+=arr[i]
        arr[i] = -arr[i]
        
        max_circular = arr_sum+normalMaxSum(arr,n)
        
        return max(max_circular,max_normal)
    
# arr = [10,13,12,11,9,9]
arr=[-5,-3]
n = len(arr)

overallMaxsum(arr,n)
# Out:
# 1
